# %% [markdown]
# <a href="https://colab.research.google.com/github/1krishnasharma/facial-landmark-detection/blob/main/Copy_of_facial_landmarks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2

# %%
def plt_imshow(title, image):
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
args = {
	"shape_predictor": "shape_predictor_68_face_landmarks.dat",
	"image": "images/example_01.jpg"
}

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('/content/sample_data/shape_predictor_68_face_landmarks.dat')

image = cv2.imread('/content/sample_data/mine.jpeg')
image = imutils.resize(image, width=500)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

rects = detector(gray, 1)

# %%
for (i, rect) in enumerate(rects):
	shape = predictor(gray, rect)
	shape = face_utils.shape_to_np(shape)

	(x, y, w, h) = face_utils.rect_to_bb(rect)
	cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

	cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
		cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 5)

	for (x, y) in shape:
		cv2.circle(image, (x, y), 1, (0, 0, 255), -1)

cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x671 at 0x7F0E8C40D810>
